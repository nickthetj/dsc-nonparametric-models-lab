# %% [markdown]
# # Nonparametric ML Models - Cumulative Lab
#
# ## Introduction
#
# In this cumulative lab, you will apply two nonparametric models you have just learned — k-nearest neighbors and decision trees — to the forest cover dataset.
#
# ## Objectives
#
# * Practice identifying and applying appropriate preprocessing steps
# * Perform an iterative modeling process, starting from a baseline model
# * Explore multiple model algorithms, and tune their hyperparameters
# * Practice choosing a final model across multiple model algorithms and evaluating its performance

# %% [markdown]
# ## Your Task: Complete an End-to-End ML Process with Nonparametric Models on the Forest Cover Dataset
#
# ![line of pine trees](https://curriculum-content.s3.amazonaws.com/data-science/images/trees.jpg)
#
# Photo by <a href="https://unsplash.com/@michaelbenz?utm_source=unsplash&utm_medium=referral&utm_content=creditCopyText">Michael Benz</a> on <a href="/s/photos/forest?utm_source=unsplash&utm_medium=referral&utm_content=creditCopyText">Unsplash</a>

# %% [markdown]
# ### Business and Data Understanding
#
# To repeat the previous description:
#
# > Here we will be using an adapted version of the forest cover dataset from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/covertype). Each record represents a 30 x 30 meter cell of land within Roosevelt National Forest in northern Colorado, which has been labeled as `Cover_Type` 1 for "Cottonwood/Willow" and `Cover_Type` 0 for "Ponderosa Pine". (The original dataset contained 7 cover types but we have simplified it.)
#
# The task is to predict the `Cover_Type` based on the available cartographic variables:

# %%
# Run this cell without changes
import pandas as pd

df = pd.read_csv('data/forest_cover.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38501 entries, 0 to 38500
# Data columns (total 53 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Elevation                           38501 non-null  int64
#  1   Aspect                              38501 non-null  int64
#  2   Slope                               38501 non-null  int64
#  3   Horizontal_Distance_To_Hydrology    38501 non-null  int64
#  4   Vertical_Distance_To_Hydrology      38501 non-null  int64
#  5   Horizontal_Distance_To_Roadways     38501 non-null  int64
#  6   Hillshade_9am                       38501 non-null  int64
#  7   Hillshade_Noon                      38501 non-null  int64
#  8   Hillshade_3pm                       38501 non-null  int64
#  9   Horizontal_Distance_To_Fire_Points  38501 non-null  int64
#  10  Wilderness_Area_1                   38501 non-null  int64
#  11  Wilderness_Area_2                   38501 non-null  int64
#  12  Wilderness_Area_3                   38501 non-null  int64
#  13  Soil_Type_1                         38501 non-null  int64
#  14  Soil_Type_2                         38501 non-null  int64
#  15  Soil_Type_3                         38501 non-null  int64
#  16  Soil_Type_4                         38501 non-null  int64
#  17  Soil_Type_5                         38501 non-null  int64
#  18  Soil_Type_6                         38501 non-null  int64
#  19  Soil_Type_7                         38501 non-null  int64
#  20  Soil_Type_8                         38501 non-null  int64
#  21  Soil_Type_9                         38501 non-null  int64
#  22  Soil_Type_10                        38501 non-null  int64
#  23  Soil_Type_11                        38501 non-null  int64
#  24  Soil_Type_12                        38501 non-null  int64
#  25  Soil_Type_13                        38501 non-null  int64
#  26  Soil_Type_14                        38501 non-null  int64
#  27  Soil_Type_15                        38501 non-null  int64
#  28  Soil_Type_16                        38501 non-null  int64
#  29  Soil_Type_17                        38501 non-null  int64
#  30  Soil_Type_18                        38501 non-null  int64
#  31  Soil_Type_19                        38501 non-null  int64
#  32  Soil_Type_20                        38501 non-null  int64
#  33  Soil_Type_21                        38501 non-null  int64
#  34  Soil_Type_22                        38501 non-null  int64
#  35  Soil_Type_23                        38501 non-null  int64
#  36  Soil_Type_24                        38501 non-null  int64
#  37  Soil_Type_25                        38501 non-null  int64
#  38  Soil_Type_26                        38501 non-null  int64
#  39  Soil_Type_27                        38501 non-null  int64
#  40  Soil_Type_28                        38501 non-null  int64
#  41  Soil_Type_29                        38501 non-null  int64
#  42  Soil_Type_30                        38501 non-null  int64
#  43  Soil_Type_31                        38501 non-null  int64
#  44  Soil_Type_32                        38501 non-null  int64
#  45  Soil_Type_33                        38501 non-null  int64
#  46  Soil_Type_34                        38501 non-null  int64
#  47  Soil_Type_35                        38501 non-null  int64
#  48  Soil_Type_36                        38501 non-null  int64
#  49  Soil_Type_37                        38501 non-null  int64
#  50  Soil_Type_38                        38501 non-null  int64
#  51  Soil_Type_39                        38501 non-null  int64
#  52  Cover_Type                          38501 non-null  int64
# dtypes: int64(53)
# memory usage: 15.6 MB

# %% [markdown]
# > As you can see, we have over 38,000 rows, each with 52 feature columns and 1 target column:
#
# > * `Elevation`: Elevation in meters
# > * `Aspect`: Aspect in degrees azimuth
# > * `Slope`: Slope in degrees
# > * `Horizontal_Distance_To_Hydrology`: Horizontal dist to nearest surface water features in meters
# > * `Vertical_Distance_To_Hydrology`: Vertical dist to nearest surface water features in meters
# > * `Horizontal_Distance_To_Roadways`: Horizontal dist to nearest roadway in meters
# > * `Hillshade_9am`: Hillshade index at 9am, summer solstice
# > * `Hillshade_Noon`: Hillshade index at noon, summer solstice
# > * `Hillshade_3pm`: Hillshade index at 3pm, summer solstice
# > * `Horizontal_Distance_To_Fire_Points`: Horizontal dist to nearest wildfire ignition points, meters
# > * `Wilderness_Area_x`: Wilderness area designation (3 columns)
# > * `Soil_Type_x`: Soil Type designation (39 columns)
# > * `Cover_Type`: 1 for cottonwood/willow, 0 for ponderosa pine
#
# This is also an imbalanced dataset, since cottonwood/willow trees are relatively rare in this forest:

# %%
# Run this cell without changes
print("Raw Counts")
print(df["Cover_Type"].value_counts())
print()
print("Percentages")
print(df["Cover_Type"].value_counts(normalize=True))
# Out:
# Raw Counts
# Cover_Type
# 0    35754
# 1     2747
# Name: count, dtype: int64
#
# Percentages
# Cover_Type
# 0    0.928651
# 1    0.071349
# Name: proportion, dtype: float64

# %% [markdown]
# Thus, a baseline model that always chose the majority class would have an accuracy of over 92%. Therefore we will want to report additional metrics at the end.

# %% [markdown]
# ### Previous Best Model
#
# In a previous lab, we used SMOTE to create additional synthetic data, then tuned the hyperparameters of a logistic regression model to get the following final model metrics:
#
# * **Log loss:** 0.13031294393913376
# * **Accuracy:** 0.9456679825472678
# * **Precision:** 0.6659919028340081
# * **Recall:** 0.47889374090247455
#
# In this lab, you will try to beat those scores using more-complex, nonparametric models.
#
# ### Modeling
#
# Although you may be aware of some additional model algorithms available from scikit-learn, for this lab you will be focusing on two of them: k-nearest neighbors and decision trees. Here are some reminders about these models:
#
# #### kNN - [documentation here](https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html)
#
# This algorithm — unlike linear models or tree-based models — does not emphasize learning the relationship between the features and the target. Instead, for a given test record, it finds the most similar records in the training set and returns an average of their target values.
#
# * **Training speed:** Fast. In theory it's just saving the training data for later, although the scikit-learn implementation has some additional logic "under the hood" to make prediction faster.
# * **Prediction speed:** Very slow. The model has to look at every record in the training set to find the k closest to the new record.
# * **Requires scaling:** Yes. The algorithm to find the nearest records is distance-based, so it matters that distances are all on the same scale.
# * **Key hyperparameters:** `n_neighbors` (how many nearest neighbors to find; too few neighbors leads to overfitting, too many leads to underfitting), `p` and `metric` (what kind of distance to use in defining "nearest" neighbors)
#
# #### Decision Trees - [documentation here](https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html)
#
# Similar to linear models (and unlike kNN), this algorithm emphasizes learning the relationship between the features and the target. However, unlike a linear model that tries to find linear relationships between each of the features and the target, decision trees look for ways to split the data based on features to decrease the entropy of the target in each split.
#
# * **Training speed:** Slow. The model is considering splits based on as many as all of the available features, and it can split on the same feature multiple times. This requires exponential computational time that increases based on the number of columns as well as the number of rows.
# * **Prediction speed:** Medium fast. Producing a prediction with a decision tree means applying several conditional statements, which is slower than something like logistic regression but faster than kNN.
# * **Requires scaling:** No. This model is not distance-based. You also can use a `LabelEncoder` rather than `OneHotEncoder` for categorical data, since this algorithm doesn't necessarily assume that the distance between `1` and `2` is the same as the distance between `2` and `3`.
# * **Key hyperparameters:** Many features relating to "pruning" the tree. By default they are set so the tree can overfit, and by setting them higher or lower (depending on the hyperparameter) you can reduce overfitting, but too much will lead to underfitting. These are: `max_depth`, `min_samples_split`, `min_samples_leaf`, `min_weight_fraction_leaf`, `max_features`, `max_leaf_nodes`, and `min_impurity_decrease`. You can also try changing the `criterion` to "entropy" or the `splitter` to "random" if you want to change the splitting logic.

# %% [markdown]
# ### Requirements
#
# #### 1. Prepare the Data for Modeling
#
# #### 2. Build a Baseline kNN Model
#
# #### 3. Build Iterative Models to Find the Best kNN Model
#
# #### 4. Build a Baseline Decision Tree Model
#
# #### 5. Build Iterative Models to Find the Best Decision Tree Model
#
# #### 6. Choose and Evaluate an Overall Best Model

# %% [markdown]
# ## 1. Prepare the Data for Modeling
#
# The target is `Cover_Type`. In the cell below, split `df` into `X` and `y`, then perform a train-test split with `random_state=42` and `stratify=y` to create variables with the standard `X_train`, `X_test`, `y_train`, `y_test` names.
#
# Include the relevant imports as you go.

# %%
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.preprocessing import StandardScaler

# %%
# Your code here
y = df['Cover_Type']
X = df.drop('Cover_Type', axis=1)
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, stratify=y)

# %% [markdown]
# Now, instantiate a `StandardScaler`, fit it on `X_train`, and create new variables `X_train_scaled` and `X_test_scaled` containing values transformed with the scaler.

# %%
# Your code here
ss = StandardScaler()
ss.fit(X_train)
# Out:
# StandardScaler()

# %%
X_train_scaled = ss.transform(X_train)
X_test_scaled = ss.transform(X_test)

# %% [markdown]
# The following code checks that everything is set up correctly:

# %%
# Run this cell without changes

# Checking that df was separated into correct X and y
assert type(X) == pd.DataFrame and X.shape == (38501, 52)
assert type(y) == pd.Series and y.shape == (38501,)

# Checking the train-test split
assert type(X_train) == pd.DataFrame and X_train.shape == (28875, 52)
assert type(X_test) == pd.DataFrame and X_test.shape == (9626, 52)
assert type(y_train) == pd.Series and y_train.shape == (28875,)
assert type(y_test) == pd.Series and y_test.shape == (9626,)

# Checking the scaling
assert X_train_scaled.shape == X_train.shape
assert round(X_train_scaled[0][0], 3) == -0.636
assert X_test_scaled.shape == X_test.shape
assert round(X_test_scaled[0][0], 3) == -1.370

# %% [markdown]
# ## 2. Build a Baseline kNN Model
#
# Build a scikit-learn kNN model with default hyperparameters. Then use `cross_val_score` with `scoring="neg_log_loss"` to find the mean log loss for this model (passing in `X_train_scaled` and `y_train` to `cross_val_score`). You'll need to find the mean of the cross-validated scores, and negate the value (either put a `-` at the beginning or multiply by `-1`) so that your answer is a log loss rather than a negative log loss.
#
# Call the resulting score `knn_baseline_log_loss`.
#
# Your code might take a minute or more to run.

# %%
from sklearn.neighbors import KNeighborsClassifier, KNeighborsRegressor

# %%
# Replace None with appropriate code

# Creating the model
knn_baseline_model = KNeighborsClassifier()
knn_baseline_model.fit(X_train_scaled, y_train)
# Perform cross-validation
knn_baseline_log_loss = cross_val_score(knn_baseline_model, X_train_scaled, y_train, scoring='neg_log_loss')

-knn_baseline_log_loss.mean()
# Out:
# 0.12964546386734577

# %% [markdown]
# Our best logistic regression model had a log loss of 0.13031294393913376
#
# Is this model better? Compare it in terms of metrics and speed.

# %%
# Replace None with appropriate text
"""
our model is slightly better. it is a bit slower perhaps?

"""

# %% [markdown]
# ## 3. Build Iterative Models to Find the Best kNN Model
#
# Build and evaluate at least two more kNN models to find the best one. Explain why you are changing the hyperparameters you are changing as you go. These models will be *slow* to run, so be thinking about what you might try next as you run them.

# %%
knn_baseline_model = KNeighborsClassifier(n_neighbors=3,n_jobs=-1)
knn_baseline_model.fit(X_train_scaled, y_train)
# Perform cross-validation
knn_baseline_log_loss = cross_val_score(knn_baseline_model, X_train_scaled, y_train, scoring='neg_log_loss')

-knn_baseline_log_loss.mean()
# Out:
# 0.1811320692968615

# %%
knn_baseline_model = KNeighborsClassifier(p=3, n_jobs=-1)
knn_baseline_model.fit(X_train_scaled, y_train)
# Perform cross-validation
knn_baseline_log_loss = cross_val_score(knn_baseline_model, X_train_scaled, y_train, scoring='neg_log_loss', verbose=3)

-knn_baseline_log_loss.mean()
# Out:
# [CV] END ............................... score: (test=-0.126) total time=   7.2s
# [CV] END ............................... score: (test=-0.101) total time=   7.7s
# [CV] END ............................... score: (test=-0.147) total time=   7.9s
# [CV] END ............................... score: (test=-0.138) total time=   8.0s
# [CV] END ............................... score: (test=-0.162) total time=   8.2s
# 0.13489929473959367

# %%
# best model
# Creating the model
knn_baseline_model = KNeighborsClassifier(n_neighbors=18, weights='distance', n_jobs=-1)
knn_baseline_model.fit(X_train_scaled, y_train)
# Perform cross-validation
knn_baseline_log_loss = cross_val_score(knn_baseline_model, X_train_scaled, y_train, scoring='neg_log_loss')

-knn_baseline_log_loss.mean()
# Out:
# 0.05585990263346273

# %%
# Your code here (add more cells as needed)

# %% [markdown]
# ## 4. Build a Baseline Decision Tree Model
#
# Now that you have chosen your best kNN model, start investigating decision tree models. First, build and evaluate a baseline decision tree model, using default hyperparameters (with the exception of `random_state=42` for reproducibility).
#
# (Use cross-validated log loss, just like with the previous models.)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt = DecisionTreeClassifier(random_state=42)
dt.fit(X_train_scaled, y_train)
dt_log_loss = cross_val_score(dt, X_train_scaled, y_train, scoring='neg_log_loss')
-dt_log_loss.mean()
# Out:
# 0.7314833207280576

# %% [markdown]
# Interpret this score. How does this compare to the log loss from our best logistic regression and best kNN models? Any guesses about why?

# %%
# Replace None with appropriate text
"""
this log loss sucks
its overfitting
"""

# %%
df.shape
# Out:
# (38501, 53)

# %% [markdown]
# ## 5. Build Iterative Models to Find the Best Decision Tree Model
#
# Build and evaluate at least two more decision tree models to find the best one. Explain why you are changing the hyperparameters you are changing as you go.

# %%
import numpy as np

# %%
# Your code here (add more cells as needed)
params = {
    'criterion': ['gini', 'entropy'],
    'min_samples_split': [412, 415, 417],
    
}

clf = GridSearchCV(
    estimator=dt,
    param_grid=params,
    cv=5,
    n_jobs=-1,
    verbose=3,
    scoring='neg_log_loss'
)

clf.fit(X_train_scaled, y_train)
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(random_state=42), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'min_samples_split': [412, 415, 417]},
#              scoring='neg_log_loss', verbose=3)

# %%
# Your code here (add more cells as needed)
print(clf.best_params_)
print(-clf.best_score_)
print(clf.best_estimator_)
# Out:
# {'criterion': 'entropy', 'min_samples_split': 415}
# 0.11438911372306701
# DecisionTreeClassifier(criterion='entropy', min_samples_split=415,
#                        random_state=42)

# %%
# Your code here (add more cells as needed)

# %% [markdown]
# ## 6. Choose and Evaluate an Overall Best Model
#
# Which model had the best performance? What type of model was it?
#
# Instantiate a variable `final_model` using your best model with the best hyperparameters.

# %%
# Replace None with appropriate code
final_model = KNeighborsClassifier(n_neighbors=18, weights='distance', n_jobs=-1)


# Fit the model on the full training data
# (scaled or unscaled depending on the model)
final_model.fit(X_train_scaled, y_train)
# Out:
# KNeighborsClassifier(n_jobs=-1, n_neighbors=18, weights='distance')

# %% [markdown]
# Now, evaluate the log loss, accuracy, precision, and recall. This code is mostly filled in for you, but you need to replace `None` with either `X_test` or `X_test_scaled` depending on the model you chose.

# %%
# Replace None with appropriate code
from sklearn.metrics import accuracy_score, precision_score, recall_score, log_loss

preds = final_model.predict(X_test_scaled)
probs = final_model.predict_proba(X_test_scaled)

print("log loss: ", log_loss(y_test, probs))
print("accuracy: ", accuracy_score(y_test, preds))
print("precision:", precision_score(y_test, preds))
print("recall:   ", recall_score(y_test, preds))
# Out:
# log loss:  0.07060999942281891
# accuracy:  0.9792229378765842
# precision: 0.9120135363790186
# recall:    0.784570596797671
# [CV 2/5] END criterion=gini, min_samples_split=5.0;, score=nan total time=   0.0s
# [CV 4/5] END criterion=gini, min_samples_split=27.5;, score=nan total time=   0.0s
# [CV 5/5] END criterion=gini, min_samples_split=50.0;, score=nan total time=   0.0s
# [CV 4/5] END criterion=entropy, min_samples_split=16.25;, score=nan total time=   0.0s
# [CV 2/5] END criterion=entropy, min_samples_split=38.75;, score=nan total time=   0.0s
# [CV 5/5] END criterion=entropy, min_samples_split=50.0;, score=nan total time=   0.0s
# [CV 1/5] END criterion=gini, min_samples_split=16.25;, score=nan total time=   0.0s
# [CV 2/5] END criterion=gini, min_samples_split=38.75;, score=nan total time=   0.0s
# [CV 3/5] END criterion=gini, min_samples_split=38.75;, score=nan total time=   0.0s
# [CV 2/5] END criterion=entropy, min_samples_split=27.5;, score=nan total time=   0.0s
# [CV 3/5] END criterion=entropy, min_samples_split=27.5;, score=nan total time=   0.0s
# [CV 5/5] END criterion=gini, min_samples_split=5;, score=0.979 total time=   0.2s
# [CV 3/5] END criterion=gini, min_samples_split=25;, score=0.981 total time=   0.2s
# [CV 5/5] END criterion=gini, min_samples_split=35;, score=0.977 total time=   0.2s
# [CV 5/5] END criterion=entropy, min_samples_split=5;, score=0.982 total time=   0.1s
# [CV 4/5] END criterion=entropy, min_samples_split=25;, score=0.977 total time=   0.2s
# [CV 4/5] END criterion=entropy, min_samples_split=45;, score=0.974 total time=   0.1s
# [CV 4/5] END .criterion=gini, min_samples_split=1;, score=nan total time=   0.0s
# [CV 2/5] END criterion=gini, min_samples_split=3;, score=0.979 total time=   0.2s
# [CV 3/5] END criterion=gini, min_samples_split=5;, score=0.983 total time=   0.2s
# [CV 4/5] END criterion=gini, min_samples_split=5;, score=0.978 total time=   0.2s
# [CV 3/5] END criterion=gini, min_samples_split=7;, score=0.983 total time=   0.2s
# [CV 4/5] END criterion=gini, min_samples_split=7;, score=0.977 total time=   0.2s
# [CV 4/5] END criterion=gini, min_samples_split=10;, score=0.976 total time=   0.2s
# [CV 5/5] END criterion=gini, min_samples_split=10;, score=0.978 total time=   0.2s
# [CV 3/5] END criterion=entropy, min_samples_split=5;, score=0.980 total time=   0.2s
# [CV 4/5] END criterion=entropy, min_samples_split=5;, score=0.979 total time=   0.2s
# [CV 1/5] END criterion=entropy, min_samples_split=7;, score=0.981 total time=   0.1s
# [CV 2/5] END criterion=entropy, min_samples_split=7;, score=0.980 total time=   0.2s
# [CV 4/5] END criterion=entropy, min_samples_split=10;, score=0.977 total time=   0.1s
# [CV 2/5] END criterion=gini, min_samples_split=2;, score=0.979 total time=   0.3s
# [CV 5/5] END criterion=gini, min_samples_split=6;, score=0.979 total time=   0.2s
# [CV 3/5] END criterion=gini, min_samples_split=10;, score=0.981 total time=   0.2s
# [CV 5/5] END criterion=entropy, min_samples_split=2;, score=0.983 total time=   0.2s
# [CV 4/5] END criterion=entropy, min_samples_split=6;, score=0.978 total time=   0.1s
# [CV 5/5] END criterion=entropy, min_samples_split=8;, score=0.983 total time=   0.2s
# [CV 2/5] END criterion=gini, min_samples_split=4;, score=-0.764 total time=   0.2s
# [CV 4/5] END criterion=gini, min_samples_split=6;, score=-0.681 total time=   0.2s
# [CV 5/5] END criterion=gini, min_samples_split=8;, score=-0.713 total time=   0.2s
# [CV 1/5] END criterion=entropy, min_samples_split=4;, score=-0.638 total time=   0.1s
# [CV 4/5] END criterion=entropy, min_samples_split=6;, score=-0.691 total time=   0.1s
# [CV 2/5] END criterion=entropy, min_samples_split=10;, score=-0.480 total time=   0.1s
# [CV 4/5] END criterion=gini, min_samples_split=10;, score=-0.594 total time=   0.2s
# [CV 5/5] END criterion=gini, min_samples_split=12;, score=-0.618 total time=   0.2s
# [CV 3/5] END criterion=gini, min_samples_split=16;, score=-0.349 total time=   0.2s
# [CV 1/5] END criterion=gini, min_samples_split=20;, score=-0.310 total time=   0.2s
# [CV 3/5] END criterion=entropy, min_samples_split=12;, score=-0.440 total time=   0.2s
# [CV 3/5] END criterion=entropy, min_samples_split=16;, score=-0.368 total time=   0.2s
# [CV 1/5] END criterion=entropy, min_samples_split=20;, score=-0.389 total time=   0.1s
# [CV 2/5] END criterion=gini, min_samples_split=50;, score=-0.305 total time=   0.2s
# [CV 3/5] END criterion=gini, min_samples_split=55;, score=-0.181 total time=   0.2s
# [CV 3/5] END criterion=gini, min_samples_split=60;, score=-0.189 total time=   0.2s
# [CV 4/5] END criterion=entropy, min_samples_split=45;, score=-0.307 total time=   0.1s
# [CV 4/5] END criterion=entropy, min_samples_split=55;, score=-0.259 total time=   0.2s
# [CV 2/5] END criterion=entropy, min_samples_split=65;, score=-0.246 total time=   0.1s
# [CV 4/5] END criterion=gini, min_samples_split=75;, score=-0.213 total time=   0.2s
# [CV 1/5] END criterion=gini, min_samples_split=150;, score=-0.104 total time=   0.2s
# [CV 4/5] END criterion=gini, min_samples_split=200;, score=-0.161 total time=   0.2s
# [CV 1/5] END criterion=entropy, min_samples_split=100;, score=-0.147 total time=   0.1s
# [CV 4/5] END criterion=entropy, min_samples_split=150;, score=-0.169 total time=   0.1s
# [CV 1/5] END criterion=entropy, min_samples_split=250;, score=-0.120 total time=   0.2s
# [CV 2/5] END criterion=gini, min_samples_split=500;, score=-0.129 total time=   0.2s
# [CV 4/5] END criterion=gini, min_samples_split=500;, score=-0.127 total time=   0.2s
# [CV 3/5] END criterion=entropy, min_samples_split=250;, score=-0.100 total time=   0.1s
# [CV 5/5] END criterion=entropy, min_samples_split=500;, score=-0.110 total time=   0.1s
# [CV 4/5] END criterion=gini, min_samples_split=400;, score=-0.121 total time=   0.2s
# [CV 4/5] END criterion=gini, min_samples_split=450;, score=-0.126 total time=   0.2s
# [CV 2/5] END criterion=gini, min_samples_split=575;, score=-0.126 total time=   0.2s
# [CV 5/5] END criterion=entropy, min_samples_split=400;, score=-0.108 total time=   0.1s
# [CV 3/5] END criterion=entropy, min_samples_split=450;, score=-0.097 total time=   0.1s
# [CV 1/5] END criterion=entropy, min_samples_split=575;, score=-0.116 total time=   0.1s
# [CV 3/5] END criterion=gini, min_samples_split=400;, score=-0.101 total time=   0.2s
# [CV 2/5] END criterion=gini, min_samples_split=437.5;, score=nan total time=   0.0s
# [CV 3/5] END criterion=gini, min_samples_split=437.5;, score=nan total time=   0.0s
# [CV 1/5] END criterion=entropy, min_samples_split=412.5;, score=nan total time=   0.0s
# [CV 2/5] END criterion=entropy, min_samples_split=412.5;, score=nan total time=   0.0s
# [CV 3/5] END criterion=entropy, min_samples_split=412.5;, score=nan total time=   0.0s
# [CV 4/5] END criterion=entropy, min_samples_split=412.5;, score=nan total time=   0.0s
# [CV 2/5] END criterion=entropy, min_samples_split=425;, score=-0.128 total time=   0.1s
# [CV 3/5] END criterion=entropy, min_samples_split=425;, score=-0.096 total time=   0.1s
# [CV 3/5] END criterion=gini, min_samples_split=400;, score=-0.101 total time=   0.2s
# [CV 2/5] END criterion=gini, min_samples_split=425;, score=-0.125 total time=   0.2s
# [CV 2/5] END criterion=gini, min_samples_split=437;, score=-0.125 total time=   0.2s
# [CV 5/5] END criterion=gini, min_samples_split=450;, score=-0.140 total time=   0.2s
# [CV 4/5] END criterion=entropy, min_samples_split=425;, score=-0.118 total time=   0.1s
# [CV 2/5] END criterion=entropy, min_samples_split=450;, score=-0.128 total time=   0.1s
# [CV 5/5] END criterion=gini, min_samples_split=400;, score=-0.134 total time=   0.2s
# [CV 1/5] END criterion=gini, min_samples_split=425;, score=-0.107 total time=   0.2s
# [CV 2/5] END criterion=gini, min_samples_split=450;, score=-0.125 total time=   0.2s
# [CV 4/5] END criterion=entropy, min_samples_split=400;, score=-0.123 total time=   0.1s
# [CV 2/5] END criterion=entropy, min_samples_split=425;, score=-0.128 total time=   0.1s
# [CV 2/5] END criterion=entropy, min_samples_split=450;, score=-0.128 total time=   0.1s
# [CV 5/5] END criterion=gini, min_samples_split=420;, score=-0.137 total time=   0.2s
# [CV 2/5] END criterion=gini, min_samples_split=430;, score=-0.125 total time=   0.2s
# [CV 4/5] END criterion=entropy, min_samples_split=425;, score=-0.118 total time=   0.1s
# [CV 3/5] END criterion=gini, min_samples_split=410;, score=-0.101 total time=   0.2s
# [CV 1/5] END criterion=gini, min_samples_split=420;, score=-0.107 total time=   0.2s
# [CV 4/5] END criterion=entropy, min_samples_split=415;, score=-0.118 total time=   0.1s
# [CV 1/5] END criterion=gini, min_samples_split=415;, score=-0.105 total time=   0.2s
# [CV 4/5] END criterion=gini, min_samples_split=417;, score=-0.123 total time=   0.2s
# [CV 4/5] END criterion=entropy, min_samples_split=415;, score=-0.118 total time=   0.1s
# [CV 5/5] END criterion=gini, min_samples_split=5.0;, score=nan total time=   0.0s
# [CV 3/5] END criterion=gini, min_samples_split=27.5;, score=nan total time=   0.0s
# [CV 3/5] END criterion=gini, min_samples_split=38.75;, score=nan total time=   0.0s
# [CV 3/5] END criterion=entropy, min_samples_split=5.0;, score=nan total time=   0.0s
# [CV 2/5] END criterion=entropy, min_samples_split=27.5;, score=nan total time=   0.0s
# [CV 5/5] END criterion=entropy, min_samples_split=38.75;, score=nan total time=   0.0s
# [CV 1/5] END criterion=gini, min_samples_split=5.0;, score=nan total time=   0.0s
# [CV 3/5] END criterion=gini, min_samples_split=16.25;, score=nan total time=   0.0s
# [CV 2/5] END criterion=gini, min_samples_split=27.5;, score=nan total time=   0.0s
# [CV 4/5] END criterion=gini, min_samples_split=38.75;, score=nan total time=   0.0s
# [CV 5/5] END criterion=gini, min_samples_split=38.75;, score=nan total time=   0.0s
# [CV 3/5] END criterion=entropy, min_samples_split=16.25;, score=nan total time=   0.0s
# [CV 4/5] END criterion=entropy, min_samples_split=16.25;, score=nan total time=   0.0s
# [CV 1/5] END criterion=gini, min_samples_split=5;, score=0.981 total time=   0.2s
# [CV 5/5] END criterion=gini, min_samples_split=15;, score=0.978 total time=   0.2s
# [CV 3/5] END criterion=gini, min_samples_split=45;, score=0.977 total time=   0.2s
# [CV 3/5] END criterion=entropy, min_samples_split=5;, score=0.980 total time=   0.1s
# [CV 1/5] END criterion=entropy, min_samples_split=25;, score=0.981 total time=   0.1s
# [CV 4/5] END criterion=entropy, min_samples_split=35;, score=0.976 total time=   0.2s
# [CV 3/5] END .criterion=gini, min_samples_split=1;, score=nan total time=   0.0s
# [CV 5/5] END criterion=gini, min_samples_split=2;, score=0.978 total time=   0.2s
# [CV 4/5] END criterion=gini, min_samples_split=4;, score=0.979 total time=   0.2s
# [CV 5/5] END criterion=gini, min_samples_split=4;, score=0.978 total time=   0.2s
# [CV 2/5] END criterion=gini, min_samples_split=8;, score=0.979 total time=   0.2s
# [CV 3/5] END criterion=gini, min_samples_split=8;, score=0.983 total time=   0.2s
# [CV 3/5] END criterion=entropy, min_samples_split=1;, score=nan total time=   0.0s
# [CV 4/5] END criterion=entropy, min_samples_split=1;, score=nan total time=   0.0s
# [CV 1/5] END criterion=entropy, min_samples_split=3;, score=0.982 total time=   0.2s
# [CV 2/5] END criterion=entropy, min_samples_split=3;, score=0.980 total time=   0.1s
# [CV 5/5] END criterion=entropy, min_samples_split=5;, score=0.982 total time=   0.2s
# [CV 1/5] END criterion=entropy, min_samples_split=6;, score=0.981 total time=   0.1s
# [CV 5/5] END criterion=entropy, min_samples_split=9;, score=0.983 total time=   0.1s
# [CV 1/5] END criterion=entropy, min_samples_split=10;, score=0.980 total time=   0.2s
# [CV 4/5] END criterion=gini, min_samples_split=2;, score=0.977 total time=   0.2s
# [CV 4/5] END criterion=gini, min_samples_split=4;, score=0.979 total time=   0.2s
# [CV 2/5] END criterion=gini, min_samples_split=8;, score=0.979 total time=   0.2s
# [CV 5/5] END criterion=gini, min_samples_split=10;, score=0.978 total time=   0.2s
# [CV 1/5] END criterion=entropy, min_samples_split=6;, score=0.981 total time=   0.1s
# [CV 2/5] END criterion=entropy, min_samples_split=10;, score=0.980 total time=   0.2s
# [CV 3/5] END criterion=gini, min_samples_split=2;, score=-0.693 total time=   0.2s
# [CV 1/5] END criterion=gini, min_samples_split=6;, score=-0.561 total time=   0.2s
# [CV 1/5] END criterion=gini, min_samples_split=10;, score=-0.443 total time=   0.2s
# [CV 5/5] END criterion=entropy, min_samples_split=2;, score=-0.624 total time=   0.1s
# [CV 5/5] END criterion=entropy, min_samples_split=6;, score=-0.548 total time=   0.1s
# [CV 3/5] END criterion=entropy, min_samples_split=10;, score=-0.479 total time=   0.1s
# [CV 5/5] END criterion=gini, min_samples_split=10;, score=-0.630 total time=   0.2s
# [CV 4/5] END criterion=gini, min_samples_split=14;, score=-0.541 total time=   0.2s
# [CV 4/5] END criterion=gini, min_samples_split=16;, score=-0.506 total time=   0.2s
# [CV 2/5] END criterion=gini, min_samples_split=20;, score=-0.465 total time=   0.2s
# [CV 5/5] END criterion=entropy, min_samples_split=12;, score=-0.400 total time=   0.2s
# [CV 1/5] END criterion=entropy, min_samples_split=16;, score=-0.392 total time=   0.1s
# [CV 3/5] END criterion=entropy, min_samples_split=18;, score=-0.369 total time=   0.1s
# [CV 4/5] END criterion=entropy, min_samples_split=20;, score=-0.369 total time=   0.1s
# [CV 3/5] END criterion=gini, min_samples_split=50;, score=-0.200 total time=   0.2s
# [CV 1/5] END criterion=gini, min_samples_split=60;, score=-0.181 total time=   0.2s
# [CV 4/5] END criterion=gini, min_samples_split=65;, score=-0.256 total time=   0.2s
# [CV 2/5] END criterion=entropy, min_samples_split=50;, score=-0.261 total time=   0.1s
# [CV 5/5] END criterion=entropy, min_samples_split=55;, score=-0.225 total time=   0.1s
# [CV 3/5] END criterion=entropy, min_samples_split=65;, score=-0.183 total time=   0.1s
# [CV 1/5] END criterion=gini, min_samples_split=100;, score=-0.118 total time=   0.2s
# [CV 3/5] END criterion=gini, min_samples_split=150;, score=-0.117 total time=   0.2s
# [CV 4/5] END criterion=gini, min_samples_split=250;, score=-0.148 total time=   0.2s
# [CV 2/5] END criterion=entropy, min_samples_split=100;, score=-0.198 total time=   0.1s
# [CV 5/5] END criterion=entropy, min_samples_split=150;, score=-0.160 total time=   0.1s
# [CV 3/5] END criterion=entropy, min_samples_split=250;, score=-0.100 total time=   0.1s
# [CV 1/5] END criterion=gini, min_samples_split=500;, score=-0.111 total time=   0.2s
# [CV 4/5] END criterion=gini, min_samples_split=750;, score=-0.139 total time=   0.2s
# [CV 3/5] END criterion=entropy, min_samples_split=500;, score=-0.099 total time=   0.1s
# [CV 5/5] END criterion=entropy, min_samples_split=750;, score=-0.115 total time=   0.1s
# [CV 2/5] END criterion=gini, min_samples_split=400;, score=-0.129 total time=   0.2s
# [CV 5/5] END criterion=gini, min_samples_split=425;, score=-0.137 total time=   0.2s
# [CV 3/5] END criterion=gini, min_samples_split=550;, score=-0.106 total time=   0.2s
# [CV 2/5] END criterion=entropy, min_samples_split=400;, score=-0.128 total time=   0.1s
# [CV 4/5] END criterion=entropy, min_samples_split=425;, score=-0.118 total time=   0.1s
# [CV 2/5] END criterion=entropy, min_samples_split=550;, score=-0.136 total time=   0.1s
# [CV 5/5] END criterion=entropy, min_samples_split=575;, score=-0.110 total time=   0.1s
# [CV 1/5] END criterion=gini, min_samples_split=412.5;, score=nan total time=   0.0s
# [CV 4/5] END criterion=gini, min_samples_split=412.5;, score=nan total time=   0.0s
# [CV 2/5] END criterion=gini, min_samples_split=425;, score=-0.125 total time=   0.2s
# [CV 3/5] END criterion=gini, min_samples_split=450;, score=-0.103 total time=   0.2s
# [CV 4/5] END criterion=gini, min_samples_split=450;, score=-0.126 total time=   0.2s
# [CV 2/5] END criterion=gini, min_samples_split=412;, score=-0.129 total time=   0.2s
# [CV 5/5] END criterion=gini, min_samples_split=412;, score=-0.137 total time=   0.2s
# [CV 3/5] END criterion=gini, min_samples_split=437;, score=-0.101 total time=   0.2s
# [CV 1/5] END criterion=entropy, min_samples_split=400;, score=-0.122 total time=   0.1s
# [CV 3/5] END criterion=entropy, min_samples_split=412;, score=-0.096 total time=   0.1s
# [CV 1/5] END criterion=entropy, min_samples_split=437;, score=-0.124 total time=   0.1s
# [CV 4/5] END criterion=entropy, min_samples_split=450;, score=-0.122 total time=   0.1s
# [CV 4/5] END criterion=gini, min_samples_split=400;, score=-0.121 total time=   0.2s
# [CV 5/5] END criterion=gini, min_samples_split=425;, score=-0.137 total time=   0.2s
# [CV 4/5] END criterion=gini, min_samples_split=450;, score=-0.126 total time=   0.2s
# [CV 5/5] END criterion=entropy, min_samples_split=400;, score=-0.108 total time=   0.1s
# [CV 3/5] END criterion=entropy, min_samples_split=425;, score=-0.096 total time=   0.1s
# [CV 5/5] END criterion=entropy, min_samples_split=437;, score=-0.110 total time=   0.1s
# [CV 2/5] END criterion=gini, min_samples_split=425;, score=-0.125 total time=   0.2s
# [CV 1/5] END criterion=entropy, min_samples_split=420;, score=-0.124 total time=   0.1s
# [CV 4/5] END criterion=entropy, min_samples_split=420;, score=-0.118 total time=   0.1s
# [CV 1/5] END criterion=entropy, min_samples_split=430;, score=-0.124 total time=   0.1s
# [CV 2/5] END criterion=gini, min_samples_split=410;, score=-0.128 total time=   0.2s
# [CV 5/5] END criterion=gini, min_samples_split=420;, score=-0.137 total time=   0.2s
# [CV 3/5] END criterion=entropy, min_samples_split=415;, score=-0.096 total time=   0.1s
# [CV 3/5] END criterion=entropy, min_samples_split=420;, score=-0.096 total time=   0.1s
# [CV 5/5] END criterion=gini, min_samples_split=412;, score=-0.137 total time=   0.2s
# [CV 3/5] END criterion=gini, min_samples_split=417;, score=-0.101 total time=   0.2s
# [CV 4/5] END criterion=entropy, min_samples_split=412;, score=-0.123 total time=   0.2s
# [CV 3/5] END criterion=gini, min_samples_split=16.25;, score=nan total time=   0.0s
# [CV 2/5] END criterion=gini, min_samples_split=38.75;, score=nan total time=   0.0s
# [CV 3/5] END criterion=gini, min_samples_split=50.0;, score=nan total time=   0.0s
# [CV 2/5] END criterion=entropy, min_samples_split=16.25;, score=nan total time=   0.0s
# [CV 3/5] END criterion=entropy, min_samples_split=27.5;, score=nan total time=   0.0s
# [CV 1/5] END criterion=entropy, min_samples_split=50.0;, score=nan total time=   0.0s
# [CV 2/5] END criterion=gini, min_samples_split=5.0;, score=nan total time=   0.0s
# [CV 5/5] END criterion=gini, min_samples_split=16.25;, score=nan total time=   0.0s
# [CV 5/5] END criterion=gini, min_samples_split=27.5;, score=nan total time=   0.0s
# [CV 4/5] END criterion=entropy, min_samples_split=5.0;, score=nan total time=   0.0s
# [CV 5/5] END criterion=entropy, min_samples_split=5.0;, score=nan total time=   0.0s
# [CV 5/5] END criterion=entropy, min_samples_split=38.75;, score=nan total time=   0.0s
# [CV 1/5] END criterion=entropy, min_samples_split=50.0;, score=nan total time=   0.0s
# [CV 2/5] END criterion=gini, min_samples_split=15;, score=0.979 total time=   0.2s
# [CV 2/5] END criterion=gini, min_samples_split=25;, score=0.978 total time=   0.2s
# [CV 4/5] END criterion=gini, min_samples_split=35;, score=0.976 total time=   0.2s
# [CV 2/5] END criterion=entropy, min_samples_split=5;, score=0.981 total time=   0.1s
# [CV 5/5] END criterion=entropy, min_samples_split=15;, score=0.982 total time=   0.1s
# [CV 3/5] END criterion=entropy, min_samples_split=35;, score=0.978 total time=   0.2s
# [CV 1/5] END .criterion=gini, min_samples_split=1;, score=nan total time=   0.0s
# [CV 4/5] END criterion=gini, min_samples_split=2;, score=0.977 total time=   0.2s
# [CV 5/5] END criterion=gini, min_samples_split=3;, score=0.978 total time=   0.2s
# [CV 1/5] END criterion=gini, min_samples_split=7;, score=0.981 total time=   0.2s
# [CV 2/5] END criterion=gini, min_samples_split=7;, score=0.979 total time=   0.2s
# [CV 5/5] END criterion=gini, min_samples_split=9;, score=0.978 total time=   0.2s
# [CV 1/5] END criterion=gini, min_samples_split=10;, score=0.981 total time=   0.2s
# [CV 5/5] END criterion=entropy, min_samples_split=3;, score=0.982 total time=   0.2s
# [CV 1/5] END criterion=entropy, min_samples_split=4;, score=0.981 total time=   0.2s
# [CV 3/5] END criterion=entropy, min_samples_split=7;, score=0.980 total time=   0.1s
# [CV 4/5] END criterion=entropy, min_samples_split=7;, score=0.979 total time=   0.2s
# [CV 5/5] END criterion=entropy, min_samples_split=10;, score=0.981 total time=   0.1s
# [CV 3/5] END criterion=gini, min_samples_split=2;, score=0.981 total time=   0.2s
# [CV 5/5] END criterion=gini, min_samples_split=4;, score=0.978 total time=   0.2s
# [CV 3/5] END criterion=gini, min_samples_split=8;, score=0.983 total time=   0.2s
# [CV 1/5] END criterion=entropy, min_samples_split=2;, score=0.982 total time=   0.1s
# [CV 3/5] END criterion=entropy, min_samples_split=4;, score=0.980 total time=   0.1s
# [CV 1/5] END criterion=entropy, min_samples_split=8;, score=0.980 total time=   0.1s
# [CV 4/5] END criterion=entropy, min_samples_split=10;, score=0.977 total time=   0.1s
# [CV 2/5] END criterion=gini, min_samples_split=2;, score=-0.749 total time=   0.2s
# [CV 4/5] END criterion=gini, min_samples_split=4;, score=-0.702 total time=   0.2s
# [CV 3/5] END criterion=gini, min_samples_split=8;, score=-0.428 total time=   0.2s
# [CV 1/5] END criterion=entropy, min_samples_split=2;, score=-0.649 total time=   0.1s
# [CV 4/5] END criterion=entropy, min_samples_split=4;, score=-0.776 total time=   0.2s
# [CV 1/5] END criterion=entropy, min_samples_split=10;, score=-0.546 total time=   0.1s
# [CV 3/5] END criterion=gini, min_samples_split=12;, score=-0.408 total time=   0.2s
# [CV 1/5] END criterion=gini, min_samples_split=16;, score=-0.357 total time=   0.2s
# [CV 3/5] END criterion=gini, min_samples_split=18;, score=-0.325 total time=   0.2s
# [CV 5/5] END criterion=gini, min_samples_split=20;, score=-0.549 total time=   0.2s
# [CV 5/5] END criterion=entropy, min_samples_split=10;, score=-0.429 total time=   0.2s
# [CV 4/5] END criterion=entropy, min_samples_split=14;, score=-0.426 total time=   0.1s
# [CV 5/5] END criterion=entropy, min_samples_split=16;, score=-0.382 total time=   0.2s
# [CV 1/5] END criterion=gini, min_samples_split=50;, score=-0.190 total time=   0.2s
# [CV 5/5] END criterion=gini, min_samples_split=55;, score=-0.302 total time=   0.2s
# [CV 3/5] END criterion=gini, min_samples_split=65;, score=-0.161 total time=   0.2s
# [CV 1/5] END criterion=entropy, min_samples_split=50;, score=-0.206 total time=   0.1s
# [CV 5/5] END criterion=entropy, min_samples_split=50;, score=-0.247 total time=   0.2s
# [CV 3/5] END criterion=entropy, min_samples_split=60;, score=-0.183 total time=   0.1s
# [CV 5/5] END criterion=entropy, min_samples_split=65;, score=-0.221 total time=   0.1s
# [CV 5/5] END criterion=gini, min_samples_split=75;, score=-0.256 total time=   0.2s
# [CV 5/5] END criterion=gini, min_samples_split=150;, score=-0.185 total time=   0.2s
# [CV 3/5] END criterion=gini, min_samples_split=250;, score=-0.103 total time=   0.2s
# [CV 5/5] END criterion=entropy, min_samples_split=75;, score=-0.187 total time=   0.1s
# [CV 3/5] END criterion=entropy, min_samples_split=150;, score=-0.156 total time=   0.2s
# [CV 2/5] END criterion=entropy, min_samples_split=250;, score=-0.156 total time=   0.2s
# [CV 1/5] END criterion=gini, min_samples_split=250;, score=-0.115 total time=   0.2s
# [CV 2/5] END criterion=gini, min_samples_split=750;, score=-0.132 total time=   0.2s
# [CV 4/5] END criterion=entropy, min_samples_split=500;, score=-0.125 total time=   0.1s
# [CV 5/5] END criterion=gini, min_samples_split=400;, score=-0.134 total time=   0.2s
# [CV 5/5] END criterion=gini, min_samples_split=450;, score=-0.140 total time=   0.2s
# [CV 4/5] END criterion=gini, min_samples_split=575;, score=-0.131 total time=   0.1s
# [CV 1/5] END criterion=entropy, min_samples_split=425;, score=-0.124 total time=   0.1s
# [CV 4/5] END criterion=entropy, min_samples_split=450;, score=-0.122 total time=   0.1s
# [CV 4/5] END criterion=entropy, min_samples_split=575;, score=-0.127 total time=   0.1s
# [CV 2/5] END criterion=gini, min_samples_split=412.5;, score=nan total time=   0.0s
# [CV 1/5] END criterion=gini, min_samples_split=425;, score=-0.107 total time=   0.2s
# [CV 1/5] END criterion=gini, min_samples_split=450;, score=-0.111 total time=   0.2s
# [CV 2/5] END criterion=gini, min_samples_split=450;, score=-0.125 total time=   0.2s
# [CV 1/5] END criterion=gini, min_samples_split=400;, score=-0.103 total time=   0.2s
# [CV 5/5] END criterion=gini, min_samples_split=425;, score=-0.137 total time=   0.2s
# [CV 2/5] END criterion=gini, min_samples_split=450;, score=-0.125 total time=   0.2s
# [CV 4/5] END criterion=entropy, min_samples_split=400;, score=-0.123 total time=   0.1s
# [CV 2/5] END criterion=entropy, min_samples_split=425;, score=-0.128 total time=   0.1s
# [CV 5/5] END criterion=entropy, min_samples_split=437;, score=-0.110 total time=   0.1s
# [CV 3/5] END criterion=gini, min_samples_split=400;, score=-0.101 total time=   0.2s
# [CV 3/5] END criterion=gini, min_samples_split=425;, score=-0.101 total time=   0.2s
# [CV 5/5] END criterion=gini, min_samples_split=437;, score=-0.139 total time=   0.2s
# [CV 3/5] END criterion=entropy, min_samples_split=400;, score=-0.096 total time=   0.1s
# [CV 1/5] END criterion=entropy, min_samples_split=425;, score=-0.124 total time=   0.1s
# [CV 2/5] END criterion=entropy, min_samples_split=437;, score=-0.128 total time=   0.1s
# [CV 1/5] END criterion=gini, min_samples_split=420;, score=-0.107 total time=   0.2s
# [CV 1/5] END criterion=gini, min_samples_split=430;, score=-0.107 total time=   0.2s
# [CV 5/5] END criterion=entropy, min_samples_split=420;, score=-0.108 total time=   0.1s
# [CV 4/5] END criterion=entropy, min_samples_split=430;, score=-0.118 total time=   0.1s
# [CV 1/5] END criterion=gini, min_samples_split=415;, score=-0.105 total time=   0.2s
# [CV 4/5] END criterion=gini, min_samples_split=420;, score=-0.123 total time=   0.1s
# [CV 2/5] END criterion=entropy, min_samples_split=415;, score=-0.128 total time=   0.1s
# [CV 1/5] END criterion=gini, min_samples_split=412;, score=-0.105 total time=   0.2s
# [CV 4/5] END criterion=gini, min_samples_split=415;, score=-0.123 total time=   0.2s
# [CV 2/5] END criterion=entropy, min_samples_split=412;, score=-0.128 total time=   0.1s
# [CV 5/5] END criterion=entropy, min_samples_split=415;, score=-0.108 total time=   0.1s
# [CV 1/5] END criterion=gini, min_samples_split=16.25;, score=nan total time=   0.0s
# [CV 5/5] END criterion=gini, min_samples_split=27.5;, score=nan total time=   0.0s
# [CV 2/5] END criterion=gini, min_samples_split=50.0;, score=nan total time=   0.0s
# [CV 5/5] END criterion=entropy, min_samples_split=5.0;, score=nan total time=   0.0s
# [CV 5/5] END criterion=entropy, min_samples_split=27.5;, score=nan total time=   0.0s
# [CV 4/5] END criterion=entropy, min_samples_split=50.0;, score=nan total time=   0.0s
# [CV 4/5] END criterion=gini, min_samples_split=16.25;, score=nan total time=   0.0s
# [CV 1/5] END criterion=gini, min_samples_split=50.0;, score=nan total time=   0.0s
# [CV 2/5] END criterion=gini, min_samples_split=50.0;, score=nan total time=   0.0s
# [CV 1/5] END criterion=entropy, min_samples_split=38.75;, score=nan total time=   0.0s
# [CV 2/5] END criterion=entropy, min_samples_split=38.75;, score=nan total time=   0.0s
# [CV 2/5] END criterion=gini, min_samples_split=5;, score=0.976 total time=   0.2s
# [CV 5/5] END criterion=gini, min_samples_split=25;, score=0.978 total time=   0.2s
# [CV 1/5] END criterion=gini, min_samples_split=45;, score=0.979 total time=   0.2s
# [CV 2/5] END criterion=entropy, min_samples_split=15;, score=0.980 total time=   0.1s
# [CV 2/5] END criterion=entropy, min_samples_split=25;, score=0.977 total time=   0.1s
# [CV 5/5] END criterion=entropy, min_samples_split=35;, score=0.979 total time=   0.2s
# [CV 3/5] END criterion=gini, min_samples_split=2;, score=0.981 total time=   0.2s
# [CV 1/5] END criterion=gini, min_samples_split=5;, score=0.981 total time=   0.2s
# [CV 2/5] END criterion=gini, min_samples_split=5;, score=0.976 total time=   0.2s
# [CV 4/5] END criterion=gini, min_samples_split=8;, score=0.977 total time=   0.2s
# [CV 5/5] END criterion=gini, min_samples_split=8;, score=0.977 total time=   0.2s
# [CV 2/5] END criterion=entropy, min_samples_split=2;, score=0.980 total time=   0.2s
# [CV 3/5] END criterion=entropy, min_samples_split=2;, score=0.981 total time=   0.1s
# [CV 4/5] END criterion=entropy, min_samples_split=4;, score=0.978 total time=   0.2s
# [CV 5/5] END criterion=entropy, min_samples_split=4;, score=0.981 total time=   0.2s
# [CV 4/5] END criterion=entropy, min_samples_split=8;, score=0.979 total time=   0.2s
# [CV 5/5] END criterion=entropy, min_samples_split=8;, score=0.983 total time=   0.1s
# [CV 1/5] END criterion=gini, min_samples_split=4;, score=0.981 total time=   0.2s
# [CV 2/5] END criterion=gini, min_samples_split=6;, score=0.979 total time=   0.2s
# [CV 4/5] END criterion=gini, min_samples_split=8;, score=0.977 total time=   0.2s
# [CV 3/5] END criterion=entropy, min_samples_split=2;, score=0.981 total time=   0.2s
# [CV 2/5] END criterion=entropy, min_samples_split=6;, score=0.979 total time=   0.1s
# [CV 4/5] END criterion=entropy, min_samples_split=8;, score=0.979 total time=   0.1s
# [CV 5/5] END criterion=gini, min_samples_split=2;, score=-0.786 total time=   0.2s
# [CV 3/5] END criterion=gini, min_samples_split=6;, score=-0.524 total time=   0.2s
# [CV 4/5] END criterion=gini, min_samples_split=8;, score=-0.635 total time=   0.2s
# [CV 2/5] END criterion=entropy, min_samples_split=2;, score=-0.730 total time=   0.1s
# [CV 3/5] END criterion=entropy, min_samples_split=4;, score=-0.646 total time=   0.1s
# [CV 1/5] END criterion=entropy, min_samples_split=8;, score=-0.574 total time=   0.1s
# [CV 4/5] END criterion=entropy, min_samples_split=10;, score=-0.569 total time=   0.1s
# [CV 2/5] END criterion=gini, min_samples_split=10;, score=-0.591 total time=   0.2s
# [CV 2/5] END criterion=gini, min_samples_split=14;, score=-0.515 total time=   0.2s
# [CV 5/5] END criterion=gini, min_samples_split=16;, score=-0.573 total time=   0.2s
# [CV 4/5] END criterion=gini, min_samples_split=20;, score=-0.442 total time=   0.2s
# [CV 2/5] END criterion=entropy, min_samples_split=12;, score=-0.447 total time=   0.2s
# [CV 2/5] END criterion=entropy, min_samples_split=16;, score=-0.430 total time=   0.2s
# [CV 5/5] END criterion=entropy, min_samples_split=18;, score=-0.377 total time=   0.1s
# [CV 4/5] END criterion=gini, min_samples_split=45;, score=-0.324 total time=   0.2s
# [CV 4/5] END criterion=gini, min_samples_split=55;, score=-0.273 total time=   0.2s
# [CV 2/5] END criterion=gini, min_samples_split=65;, score=-0.292 total time=   0.2s
# [CV 5/5] END criterion=entropy, min_samples_split=45;, score=-0.257 total time=   0.1s
# [CV 3/5] END criterion=entropy, min_samples_split=55;, score=-0.201 total time=   0.2s
# [CV 5/5] END criterion=entropy, min_samples_split=60;, score=-0.221 total time=   0.1s
# [CV 3/5] END criterion=gini, min_samples_split=100;, score=-0.118 total time=   0.2s
# [CV 1/5] END criterion=gini, min_samples_split=200;, score=-0.107 total time=   0.2s
# [CV 2/5] END criterion=gini, min_samples_split=250;, score=-0.179 total time=   0.2s
# [CV 3/5] END criterion=entropy, min_samples_split=75;, score=-0.172 total time=   0.1s
# [CV 5/5] END criterion=entropy, min_samples_split=100;, score=-0.161 total time=   0.1s
# [CV 3/5] END criterion=entropy, min_samples_split=200;, score=-0.136 total time=   0.2s
# [CV 3/5] END criterion=gini, min_samples_split=250;, score=-0.103 total time=   0.2s
# [CV 3/5] END criterion=gini, min_samples_split=750;, score=-0.115 total time=   0.2s
# [CV 2/5] END criterion=entropy, min_samples_split=500;, score=-0.136 total time=   0.1s
# [CV 2/5] END criterion=entropy, min_samples_split=750;, score=-0.131 total time=   0.1s
# [CV 3/5] END criterion=gini, min_samples_split=400;, score=-0.101 total time=   0.2s
# [CV 1/5] END criterion=gini, min_samples_split=550;, score=-0.108 total time=   0.2s
# [CV 3/5] END criterion=gini, min_samples_split=575;, score=-0.107 total time=   0.2s
# [CV 2/5] END criterion=entropy, min_samples_split=425;, score=-0.128 total time=   0.1s
# [CV 5/5] END criterion=entropy, min_samples_split=450;, score=-0.110 total time=   0.1s
# [CV 2/5] END criterion=entropy, min_samples_split=575;, score=-0.126 total time=   0.1s
# [CV 4/5] END criterion=gini, min_samples_split=400;, score=-0.121 total time=   0.2s
# [CV 5/5] END criterion=gini, min_samples_split=425;, score=-0.137 total time=   0.2s
# [CV 4/5] END criterion=entropy, min_samples_split=425;, score=-0.118 total time=   0.1s
# [CV 5/5] END criterion=entropy, min_samples_split=425;, score=-0.108 total time=   0.1s
# [CV 4/5] END criterion=gini, min_samples_split=400;, score=-0.121 total time=   0.2s
# [CV 4/5] END criterion=gini, min_samples_split=412;, score=-0.121 total time=   0.2s
# [CV 4/5] END criterion=gini, min_samples_split=437;, score=-0.122 total time=   0.2s
# [CV 2/5] END criterion=entropy, min_samples_split=400;, score=-0.128 total time=   0.1s
# [CV 4/5] END criterion=entropy, min_samples_split=412;, score=-0.123 total time=   0.1s
# [CV 2/5] END criterion=entropy, min_samples_split=437;, score=-0.128 total time=   0.1s
# [CV 5/5] END criterion=entropy, min_samples_split=450;, score=-0.110 total time=   0.1s
# [CV 2/5] END criterion=gini, min_samples_split=400;, score=-0.129 total time=   0.2s
# [CV 5/5] END criterion=gini, min_samples_split=412;, score=-0.137 total time=   0.2s
# [CV 3/5] END criterion=gini, min_samples_split=437;, score=-0.101 total time=   0.1s
# [CV 5/5] END criterion=gini, min_samples_split=450;, score=-0.140 total time=   0.2s
# [CV 5/5] END criterion=entropy, min_samples_split=412;, score=-0.108 total time=   0.1s
# [CV 4/5] END criterion=entropy, min_samples_split=437;, score=-0.122 total time=   0.1s
# [CV 4/5] END criterion=gini, min_samples_split=420;, score=-0.123 total time=   0.2s
# [CV 4/5] END criterion=gini, min_samples_split=425;, score=-0.123 total time=   0.2s
# [CV 2/5] END criterion=entropy, min_samples_split=420;, score=-0.128 total time=   0.1s
# [CV 5/5] END criterion=entropy, min_samples_split=425;, score=-0.108 total time=   0.1s
# [CV 5/5] END criterion=gini, min_samples_split=410;, score=-0.134 total time=   0.2s
# [CV 4/5] END criterion=gini, min_samples_split=415;, score=-0.123 total time=   0.2s
# [CV 5/5] END criterion=entropy, min_samples_split=410;, score=-0.108 total time=   0.1s
# [CV 4/5] END criterion=entropy, min_samples_split=420;, score=-0.118 total time=   0.1s
# [CV 2/5] END criterion=gini, min_samples_split=412;, score=-0.129 total time=   0.2s
# [CV 1/5] END criterion=gini, min_samples_split=417;, score=-0.107 total time=   0.2s
# [CV 5/5] END criterion=entropy, min_samples_split=412;, score=-0.108 total time=   0.1s
# [CV 1/5] END criterion=entropy, min_samples_split=417;, score=-0.124 total time=   0.1s
# [CV 2/5] END criterion=gini, min_samples_split=16.25;, score=nan total time=   0.0s
# [CV 4/5] END criterion=gini, min_samples_split=16.25;, score=nan total time=   0.0s
# [CV 1/5] END criterion=gini, min_samples_split=38.75;, score=nan total time=   0.0s
# [CV 4/5] END criterion=gini, min_samples_split=50.0;, score=nan total time=   0.0s
# [CV 1/5] END criterion=entropy, min_samples_split=16.25;, score=nan total time=   0.0s
# [CV 1/5] END criterion=entropy, min_samples_split=27.5;, score=nan total time=   0.0s
# [CV 3/5] END criterion=entropy, min_samples_split=38.75;, score=nan total time=   0.0s
# [CV 2/5] END criterion=gini, min_samples_split=16.25;, score=nan total time=   0.0s
# [CV 3/5] END criterion=gini, min_samples_split=50.0;, score=nan total time=   0.0s
# [CV 4/5] END criterion=gini, min_samples_split=50.0;, score=nan total time=   0.0s
# [CV 5/5] END criterion=entropy, min_samples_split=16.25;, score=nan total time=   0.0s
# [CV 1/5] END criterion=entropy, min_samples_split=27.5;, score=nan total time=   0.0s
# [CV 5/5] END criterion=entropy, min_samples_split=50.0;, score=nan total time=   0.0s
# [CV 3/5] END criterion=gini, min_samples_split=15;, score=0.982 total time=   0.2s
# [CV 1/5] END criterion=gini, min_samples_split=35;, score=0.980 total time=   0.2s
# [CV 4/5] END criterion=gini, min_samples_split=45;, score=0.976 total time=   0.2s
# [CV 1/5] END criterion=entropy, min_samples_split=15;, score=0.980 total time=   0.1s
# [CV 3/5] END criterion=entropy, min_samples_split=25;, score=0.981 total time=   0.1s
# [CV 1/5] END criterion=entropy, min_samples_split=45;, score=0.978 total time=   0.2s
# [CV 2/5] END .criterion=gini, min_samples_split=1;, score=nan total time=   0.0s
# [CV 3/5] END criterion=gini, min_samples_split=3;, score=0.984 total time=   0.2s
# [CV 2/5] END criterion=gini, min_samples_split=4;, score=0.977 total time=   0.2s
# [CV 3/5] END criterion=gini, min_samples_split=4;, score=0.982 total time=   0.2s
# [CV 5/5] END criterion=gini, min_samples_split=7;, score=0.978 total time=   0.2s
# [CV 1/5] END criterion=gini, min_samples_split=8;, score=0.982 total time=   0.2s
# [CV 1/5] END criterion=entropy, min_samples_split=1;, score=nan total time=   0.0s
# [CV 2/5] END criterion=entropy, min_samples_split=1;, score=nan total time=   0.0s
# [CV 5/5] END criterion=entropy, min_samples_split=1;, score=nan total time=   0.0s
# [CV 1/5] END criterion=entropy, min_samples_split=2;, score=0.982 total time=   0.2s
# [CV 2/5] END criterion=entropy, min_samples_split=6;, score=0.979 total time=   0.2s
# [CV 3/5] END criterion=entropy, min_samples_split=6;, score=0.980 total time=   0.2s
# [CV 3/5] END criterion=entropy, min_samples_split=9;, score=0.981 total time=   0.1s
# [CV 4/5] END criterion=entropy, min_samples_split=9;, score=0.977 total time=   0.1s
# [CV 1/5] END criterion=gini, min_samples_split=2;, score=0.983 total time=   0.2s
# [CV 1/5] END criterion=gini, min_samples_split=6;, score=0.980 total time=   0.2s
# [CV 5/5] END criterion=gini, min_samples_split=8;, score=0.977 total time=   0.2s
# [CV 2/5] END criterion=entropy, min_samples_split=2;, score=0.980 total time=   0.2s
# [CV 4/5] END criterion=entropy, min_samples_split=4;, score=0.978 total time=   0.1s
# [CV 2/5] END criterion=entropy, min_samples_split=8;, score=0.980 total time=   0.1s
# [CV 5/5] END criterion=entropy, min_samples_split=10;, score=0.981 total time=   0.1s
# [CV 4/5] END criterion=gini, min_samples_split=2;, score=-0.811 total time=   0.2s
# [CV 2/5] END criterion=gini, min_samples_split=6;, score=-0.655 total time=   0.2s
# [CV 2/5] END criterion=gini, min_samples_split=8;, score=-0.597 total time=   0.2s
# [CV 5/5] END criterion=gini, min_samples_split=10;, score=-0.630 total time=   0.2s
# [CV 2/5] END criterion=entropy, min_samples_split=6;, score=-0.629 total time=   0.2s
# [CV 3/5] END criterion=entropy, min_samples_split=8;, score=-0.533 total time=   0.1s
# [CV 3/5] END criterion=gini, min_samples_split=10;, score=-0.425 total time=   0.2s
# [CV 1/5] END criterion=gini, min_samples_split=14;, score=-0.382 total time=   0.2s
# [CV 2/5] END criterion=gini, min_samples_split=18;, score=-0.469 total time=   0.2s
# [CV 3/5] END criterion=gini, min_samples_split=20;, score=-0.303 total time=   0.2s
# [CV 1/5] END criterion=entropy, min_samples_split=12;, score=-0.469 total time=   0.2s
# [CV 3/5] END criterion=entropy, min_samples_split=14;, score=-0.410 total time=   0.2s
# [CV 4/5] END criterion=entropy, min_samples_split=18;, score=-0.387 total time=   0.1s
# [CV 1/5] END criterion=gini, min_samples_split=45;, score=-0.194 total time=   0.2s
# [CV 1/5] END criterion=gini, min_samples_split=55;, score=-0.179 total time=   0.2s
# [CV 4/5] END criterion=gini, min_samples_split=60;, score=-0.267 total time=   0.2s
# [CV 1/5] END criterion=entropy, min_samples_split=45;, score=-0.199 total time=   0.1s
# [CV 4/5] END criterion=entropy, min_samples_split=50;, score=-0.277 total time=   0.2s
# [CV 2/5] END criterion=entropy, min_samples_split=60;, score=-0.232 total time=   0.1s
# [CV 1/5] END criterion=gini, min_samples_split=75;, score=-0.161 total time=   0.2s
# [CV 4/5] END criterion=gini, min_samples_split=100;, score=-0.192 total time=   0.2s
# [CV 2/5] END criterion=gini, min_samples_split=200;, score=-0.195 total time=   0.2s
# [CV 1/5] END criterion=entropy, min_samples_split=75;, score=-0.161 total time=   0.1s
# [CV 3/5] END criterion=entropy, min_samples_split=100;, score=-0.177 total time=   0.1s
# [CV 1/5] END criterion=entropy, min_samples_split=200;, score=-0.116 total time=   0.1s
# [CV 4/5] END criterion=entropy, min_samples_split=250;, score=-0.129 total time=   0.1s
# [CV 3/5] END criterion=gini, min_samples_split=500;, score=-0.106 total time=   0.2s
# [CV 5/5] END criterion=gini, min_samples_split=500;, score=-0.135 total time=   0.2s
# [CV 2/5] END criterion=entropy, min_samples_split=250;, score=-0.156 total time=   0.1s
# [CV 1/5] END criterion=entropy, min_samples_split=750;, score=-0.122 total time=   0.1s
# [CV 2/5] END criterion=gini, min_samples_split=425;, score=-0.125 total time=   0.2s
# [CV 2/5] END criterion=gini, min_samples_split=450;, score=-0.125 total time=   0.2s
# [CV 4/5] END criterion=gini, min_samples_split=550;, score=-0.128 total time=   0.1s
# [CV 1/5] END criterion=entropy, min_samples_split=400;, score=-0.122 total time=   0.1s
# [CV 3/5] END criterion=entropy, min_samples_split=425;, score=-0.096 total time=   0.1s
# [CV 1/5] END criterion=entropy, min_samples_split=550;, score=-0.116 total time=   0.1s
# [CV 3/5] END criterion=entropy, min_samples_split=575;, score=-0.100 total time=   0.1s
# [CV 3/5] END criterion=gini, min_samples_split=412.5;, score=nan total time=   0.0s
# [CV 5/5] END criterion=gini, min_samples_split=412.5;, score=nan total time=   0.0s
# [CV 3/5] END criterion=gini, min_samples_split=425;, score=-0.101 total time=   0.1s
# [CV 5/5] END criterion=gini, min_samples_split=450;, score=-0.140 total time=   0.2s
# [CV 1/5] END criterion=entropy, min_samples_split=400;, score=-0.122 total time=   0.1s
# [CV 5/5] END criterion=entropy, min_samples_split=450;, score=-0.110 total time=   0.1s
# [CV 2/5] END criterion=gini, min_samples_split=400;, score=-0.129 total time=   0.2s
# [CV 3/5] END criterion=gini, min_samples_split=425;, score=-0.101 total time=   0.2s
# [CV 5/5] END criterion=gini, min_samples_split=437;, score=-0.139 total time=   0.2s
# [CV 3/5] END criterion=entropy, min_samples_split=400;, score=-0.096 total time=   0.1s
# [CV 5/5] END criterion=entropy, min_samples_split=412;, score=-0.108 total time=   0.1s
# [CV 3/5] END criterion=entropy, min_samples_split=437;, score=-0.096 total time=   0.1s
# [CV 1/5] END criterion=gini, min_samples_split=400;, score=-0.103 total time=   0.2s
# [CV 4/5] END criterion=gini, min_samples_split=412;, score=-0.121 total time=   0.1s
# [CV 2/5] END criterion=gini, min_samples_split=437;, score=-0.125 total time=   0.2s
# [CV 1/5] END criterion=entropy, min_samples_split=400;, score=-0.122 total time=   0.1s
# [CV 2/5] END criterion=entropy, min_samples_split=412;, score=-0.128 total time=   0.1s
# [CV 5/5] END criterion=entropy, min_samples_split=425;, score=-0.108 total time=   0.1s
# [CV 3/5] END criterion=entropy, min_samples_split=450;, score=-0.097 total time=   0.1s
# [CV 3/5] END criterion=gini, min_samples_split=420;, score=-0.101 total time=   0.2s
# [CV 5/5] END criterion=gini, min_samples_split=425;, score=-0.137 total time=   0.1s
# [CV 3/5] END criterion=entropy, min_samples_split=420;, score=-0.096 total time=   0.1s
# [CV 2/5] END criterion=entropy, min_samples_split=430;, score=-0.128 total time=   0.1s
# [CV 3/5] END criterion=gini, min_samples_split=415;, score=-0.101 total time=   0.2s
# [CV 3/5] END criterion=gini, min_samples_split=420;, score=-0.101 total time=   0.1s
# [CV 3/5] END criterion=entropy, min_samples_split=410;, score=-0.096 total time=   0.1s
# [CV 1/5] END criterion=entropy, min_samples_split=420;, score=-0.124 total time=   0.1s
# [CV 3/5] END criterion=gini, min_samples_split=412;, score=-0.101 total time=   0.2s
# [CV 2/5] END criterion=gini, min_samples_split=417;, score=-0.129 total time=   0.2s
# [CV 2/5] END criterion=entropy, min_samples_split=415;, score=-0.128 total time=   0.1s
# [CV 5/5] END criterion=entropy, min_samples_split=417;, score=-0.108 total time=   0.1s
# [CV 1/5] END criterion=gini, min_samples_split=5.0;, score=nan total time=   0.0s
# [CV 5/5] END criterion=gini, min_samples_split=16.25;, score=nan total time=   0.0s
# [CV 4/5] END criterion=gini, min_samples_split=38.75;, score=nan total time=   0.0s
# [CV 1/5] END criterion=entropy, min_samples_split=5.0;, score=nan total time=   0.0s
# [CV 4/5] END criterion=entropy, min_samples_split=27.5;, score=nan total time=   0.0s
# [CV 2/5] END criterion=entropy, min_samples_split=50.0;, score=nan total time=   0.0s
# [CV 5/5] END criterion=gini, min_samples_split=5.0;, score=nan total time=   0.0s
# [CV 4/5] END criterion=gini, min_samples_split=27.5;, score=nan total time=   0.0s
# [CV 2/5] END criterion=entropy, min_samples_split=5.0;, score=nan total time=   0.0s
# [CV 3/5] END criterion=entropy, min_samples_split=5.0;, score=nan total time=   0.0s
# [CV 4/5] END criterion=entropy, min_samples_split=27.5;, score=nan total time=   0.0s
# [CV 5/5] END criterion=entropy, min_samples_split=27.5;, score=nan total time=   0.0s
# [CV 4/5] END criterion=entropy, min_samples_split=50.0;, score=nan total time=   0.0s
# [CV 4/5] END criterion=gini, min_samples_split=5;, score=0.978 total time=   0.2s
# [CV 4/5] END criterion=gini, min_samples_split=15;, score=0.976 total time=   0.2s
# [CV 3/5] END criterion=gini, min_samples_split=35;, score=0.981 total time=   0.2s
# [CV 5/5] END criterion=gini, min_samples_split=45;, score=0.977 total time=   0.2s
# [CV 4/5] END criterion=entropy, min_samples_split=15;, score=0.978 total time=   0.1s
# [CV 1/5] END criterion=entropy, min_samples_split=35;, score=0.980 total time=   0.1s
# [CV 3/5] END criterion=entropy, min_samples_split=45;, score=0.979 total time=   0.1s
# [CV 2/5] END criterion=gini, min_samples_split=2;, score=0.979 total time=   0.2s
# [CV 4/5] END criterion=gini, min_samples_split=3;, score=0.978 total time=   0.2s
# [CV 2/5] END criterion=gini, min_samples_split=6;, score=0.979 total time=   0.2s
# [CV 3/5] END criterion=gini, min_samples_split=6;, score=0.982 total time=   0.2s
# [CV 3/5] END criterion=gini, min_samples_split=9;, score=0.983 total time=   0.2s
# [CV 4/5] END criterion=gini, min_samples_split=9;, score=0.976 total time=   0.2s
# [CV 3/5] END criterion=entropy, min_samples_split=3;, score=0.981 total time=   0.2s
# [CV 4/5] END criterion=entropy, min_samples_split=3;, score=0.979 total time=   0.1s
# [CV 4/5] END criterion=entropy, min_samples_split=6;, score=0.978 total time=   0.2s
# [CV 5/5] END criterion=entropy, min_samples_split=6;, score=0.982 total time=   0.2s
# [CV 1/5] END criterion=entropy, min_samples_split=9;, score=0.981 total time=   0.1s
# [CV 2/5] END criterion=entropy, min_samples_split=9;, score=0.980 total time=   0.2s
# [CV 2/5] END criterion=entropy, min_samples_split=10;, score=0.980 total time=   0.1s
# [CV 5/5] END criterion=gini, min_samples_split=2;, score=0.978 total time=   0.2s
# [CV 3/5] END criterion=gini, min_samples_split=6;, score=0.982 total time=   0.2s
# [CV 2/5] END criterion=gini, min_samples_split=10;, score=0.979 total time=   0.2s
# [CV 4/5] END criterion=entropy, min_samples_split=2;, score=0.980 total time=   0.2s
# [CV 3/5] END criterion=entropy, min_samples_split=6;, score=0.980 total time=   0.1s
# [CV 1/5] END criterion=entropy, min_samples_split=10;, score=0.980 total time=   0.1s
# [CV 1/5] END criterion=gini, min_samples_split=4;, score=-0.620 total time=   0.2s
# [CV 5/5] END criterion=gini, min_samples_split=6;, score=-0.692 total time=   0.2s
# [CV 3/5] END criterion=gini, min_samples_split=10;, score=-0.425 total time=   0.2s
# [CV 4/5] END criterion=entropy, min_samples_split=2;, score=-0.724 total time=   0.1s
# [CV 1/5] END criterion=entropy, min_samples_split=6;, score=-0.627 total time=   0.1s
# [CV 2/5] END criterion=entropy, min_samples_split=8;, score=-0.575 total time=   0.1s
# [CV 5/5] END criterion=entropy, min_samples_split=10;, score=-0.429 total time=   0.1s
# [CV 2/5] END criterion=gini, min_samples_split=12;, score=-0.593 total time=   0.2s
# [CV 5/5] END criterion=gini, min_samples_split=14;, score=-0.578 total time=   0.2s
# [CV 4/5] END criterion=gini, min_samples_split=18;, score=-0.477 total time=   0.2s
# ...
# [CV 1/5] END criterion=gini, min_samples_split=2;, score=0.983 total time=   0.3s
# [CV 1/5] END criterion=gini, min_samples_split=4;, score=0.981 total time=   0.2s
# [CV 4/5] END criterion=gini, min_samples_split=6;, score=0.977 total time=   0.2s
# [CV 5/5] END criterion=gini, min_samples_split=6;, score=0.979 total time=   0.2s
# [CV 2/5] END criterion=gini, min_samples_split=10;, score=0.979 total time=   0.2s
# [CV 3/5] END criterion=gini, min_samples_split=10;, score=0.981 total time=   0.3s
# [CV 1/5] END criterion=entropy, min_samples_split=5;, score=0.981 total time=   0.1s
# [CV 2/5] END criterion=entropy, min_samples_split=5;, score=0.981 total time=   0.2s
# [CV 2/5] END criterion=entropy, min_samples_split=8;, score=0.980 total time=   0.2s
# [CV 3/5] END criterion=entropy, min_samples_split=8;, score=0.980 total time=   0.1s
# [CV 3/5] END criterion=gini, min_samples_split=4;, score=0.982 total time=   0.3s
# [CV 1/5] END criterion=gini, min_samples_split=8;, score=0.982 total time=   0.2s
# [CV 4/5] END criterion=gini, min_samples_split=10;, score=0.976 total time=   0.2s
# [CV 2/5] END criterion=entropy, min_samples_split=4;, score=0.981 total time=   0.2s
# [CV 5/5] END criterion=entropy, min_samples_split=6;, score=0.982 total time=   0.1s
# [CV 3/5] END criterion=entropy, min_samples_split=10;, score=0.981 total time=   0.1s
# [CV 3/5] END criterion=gini, min_samples_split=4;, score=-0.523 total time=   0.2s
# [CV 1/5] END criterion=gini, min_samples_split=8;, score=-0.441 total time=   0.2s
# [CV 2/5] END criterion=gini, min_samples_split=10;, score=-0.591 total time=   0.2s
# [CV 3/5] END criterion=entropy, min_samples_split=2;, score=-0.680 total time=   0.1s
# [CV 5/5] END criterion=entropy, min_samples_split=4;, score=-0.602 total time=   0.2s
# [CV 4/5] END criterion=entropy, min_samples_split=8;, score=-0.553 total time=   0.1s
# [CV 1/5] END criterion=gini, min_samples_split=10;, score=-0.443 total time=   0.2s
# [CV 4/5] END criterion=gini, min_samples_split=12;, score=-0.577 total time=   0.2s
# [CV 2/5] END criterion=gini, min_samples_split=16;, score=-0.511 total time=   0.2s
# [CV 5/5] END criterion=gini, min_samples_split=18;, score=-0.548 total time=   0.2s
# [CV 3/5] END criterion=entropy, min_samples_split=10;, score=-0.479 total time=   0.2s
# [CV 1/5] END criterion=entropy, min_samples_split=14;, score=-0.435 total time=   0.1s
# [CV 4/5] END criterion=entropy, min_samples_split=16;, score=-0.398 total time=   0.1s
# [CV 2/5] END criterion=entropy, min_samples_split=20;, score=-0.383 total time=   0.1s
# [CV 2/5] END criterion=gini, min_samples_split=45;, score=-0.335 total time=   0.2s
# [CV 4/5] END criterion=gini, min_samples_split=50;, score=-0.285 total time=   0.2s
# [CV 5/5] END criterion=gini, min_samples_split=60;, score=-0.286 total time=   0.2s
# [CV 2/5] END criterion=entropy, min_samples_split=45;, score=-0.255 total time=   0.1s
# [CV 1/5] END criterion=entropy, min_samples_split=55;, score=-0.188 total time=   0.2s
# [CV 1/5] END criterion=entropy, min_samples_split=65;, score=-0.166 total time=   0.1s
# [CV 2/5] END criterion=gini, min_samples_split=75;, score=-0.287 total time=   0.2s
# [CV 4/5] END criterion=gini, min_samples_split=150;, score=-0.161 total time=   0.2s
# [CV 1/5] END criterion=gini, min_samples_split=250;, score=-0.115 total time=   0.2s
# [CV 4/5] END criterion=entropy, min_samples_split=75;, score=-0.229 total time=   0.1s
# [CV 2/5] END criterion=entropy, min_samples_split=150;, score=-0.204 total time=   0.2s
# [CV 5/5] END criterion=entropy, min_samples_split=200;, score=-0.146 total time=   0.2s
# [CV 4/5] END criterion=gini, min_samples_split=250;, score=-0.148 total time=   0.2s
# [CV 5/5] END criterion=gini, min_samples_split=750;, score=-0.143 total time=   0.2s
# [CV 1/5] END criterion=entropy, min_samples_split=500;, score=-0.115 total time=   0.1s
# [CV 4/5] END criterion=entropy, min_samples_split=750;, score=-0.135 total time=   0.1s
# [CV 3/5] END criterion=gini, min_samples_split=425;, score=-0.101 total time=   0.2s
# [CV 3/5] END criterion=gini, min_samples_split=450;, score=-0.103 total time=   0.1s
# [CV 2/5] END criterion=gini, min_samples_split=550;, score=-0.132 total time=   0.1s
# [CV 5/5] END criterion=gini, min_samples_split=575;, score=-0.139 total time=   0.1s
# [CV 5/5] END criterion=entropy, min_samples_split=425;, score=-0.108 total time=   0.1s
# [CV 3/5] END criterion=entropy, min_samples_split=550;, score=-0.099 total time=   0.1s
# [CV 1/5] END criterion=gini, min_samples_split=400;, score=-0.103 total time=   0.2s
# [CV 4/5] END criterion=gini, min_samples_split=425;, score=-0.123 total time=   0.1s
# [CV 5/5] END criterion=entropy, min_samples_split=412.5;, score=nan total time=   0.0s
# [CV 1/5] END criterion=entropy, min_samples_split=425;, score=-0.124 total time=   0.1s
# [CV 1/5] END criterion=entropy, min_samples_split=437.5;, score=nan total time=   0.0s
# [CV 2/5] END criterion=entropy, min_samples_split=437.5;, score=nan total time=   0.0s
# [CV 5/5] END criterion=entropy, min_samples_split=437.5;, score=nan total time=   0.0s
# [CV 1/5] END criterion=entropy, min_samples_split=450;, score=-0.125 total time=   0.1s
# [CV 1/5] END criterion=gini, min_samples_split=412;, score=-0.105 total time=   0.2s
# [CV 4/5] END criterion=gini, min_samples_split=425;, score=-0.123 total time=   0.2s
# [CV 3/5] END criterion=gini, min_samples_split=450;, score=-0.103 total time=   0.2s
# [CV 1/5] END criterion=entropy, min_samples_split=412;, score=-0.122 total time=   0.1s
# [CV 1/5] END criterion=entropy, min_samples_split=425;, score=-0.124 total time=   0.1s
# [CV 4/5] END criterion=entropy, min_samples_split=437;, score=-0.122 total time=   0.1s
# [CV 2/5] END criterion=gini, min_samples_split=412;, score=-0.129 total time=   0.2s
# [CV 2/5] END criterion=gini, min_samples_split=425;, score=-0.125 total time=   0.2s
# [CV 1/5] END criterion=gini, min_samples_split=450;, score=-0.111 total time=   0.3s
# [CV 3/5] END criterion=entropy, min_samples_split=412;, score=-0.096 total time=   0.1s
# [CV 1/5] END criterion=entropy, min_samples_split=437;, score=-0.124 total time=   0.1s
# [CV 4/5] END criterion=entropy, min_samples_split=450;, score=-0.122 total time=   0.1s
# [CV 1/5] END criterion=gini, min_samples_split=425;, score=-0.107 total time=   0.2s
# [CV 5/5] END criterion=gini, min_samples_split=430;, score=-0.137 total time=   0.2s
# [CV 1/5] END criterion=entropy, min_samples_split=425;, score=-0.124 total time=   0.1s
# [CV 3/5] END criterion=entropy, min_samples_split=430;, score=-0.096 total time=   0.1s
# [CV 2/5] END criterion=gini, min_samples_split=415;, score=-0.129 total time=   0.2s
# [CV 2/5] END criterion=gini, min_samples_split=420;, score=-0.125 total time=   0.2s
# [CV 1/5] END criterion=entropy, min_samples_split=415;, score=-0.122 total time=   0.1s
# [CV 2/5] END criterion=entropy, min_samples_split=420;, score=-0.128 total time=   0.1s
# [CV 4/5] END criterion=gini, min_samples_split=412;, score=-0.121 total time=   0.2s
# [CV 5/5] END criterion=gini, min_samples_split=415;, score=-0.137 total time=   0.2s
# [CV 3/5] END criterion=entropy, min_samples_split=415;, score=-0.096 total time=   0.1s
# [CV 2/5] END criterion=entropy, min_samples_split=417;, score=-0.128 total time=   0.1s
# [CV 4/5] END criterion=gini, min_samples_split=5.0;, score=nan total time=   0.0s
# [CV 2/5] END criterion=gini, min_samples_split=27.5;, score=nan total time=   0.0s
# [CV 5/5] END criterion=gini, min_samples_split=38.75;, score=nan total time=   0.0s
# [CV 2/5] END criterion=entropy, min_samples_split=5.0;, score=nan total time=   0.0s
# [CV 5/5] END criterion=entropy, min_samples_split=16.25;, score=nan total time=   0.0s
# [CV 4/5] END criterion=entropy, min_samples_split=38.75;, score=nan total time=   0.0s
# [CV 3/5] END criterion=gini, min_samples_split=5.0;, score=nan total time=   0.0s
# [CV 1/5] END criterion=gini, min_samples_split=27.5;, score=nan total time=   0.0s
# [CV 1/5] END criterion=gini, min_samples_split=38.75;, score=nan total time=   0.0s
# [CV 1/5] END criterion=entropy, min_samples_split=16.25;, score=nan total time=   0.0s
# [CV 2/5] END criterion=entropy, min_samples_split=16.25;, score=nan total time=   0.0s
# [CV 3/5] END criterion=entropy, min_samples_split=38.75;, score=nan total time=   0.0s
# [CV 4/5] END criterion=entropy, min_samples_split=38.75;, score=nan total time=   0.0s
# [CV 3/5] END criterion=gini, min_samples_split=5;, score=0.983 total time=   0.2s
# [CV 1/5] END criterion=gini, min_samples_split=25;, score=0.982 total time=   0.2s
# [CV 2/5] END criterion=gini, min_samples_split=45;, score=0.975 total time=   0.2s
# [CV 4/5] END criterion=entropy, min_samples_split=5;, score=0.979 total time=   0.2s
# [CV 5/5] END criterion=entropy, min_samples_split=25;, score=0.981 total time=   0.2s
# [CV 2/5] END criterion=entropy, min_samples_split=45;, score=0.976 total time=   0.1s
# [CV 5/5] END .criterion=gini, min_samples_split=1;, score=nan total time=   0.0s
# [CV 1/5] END criterion=gini, min_samples_split=3;, score=0.982 total time=   0.2s
# [CV 5/5] END criterion=gini, min_samples_split=5;, score=0.979 total time=   0.2s
# [CV 1/5] END criterion=gini, min_samples_split=6;, score=0.980 total time=   0.2s
# [CV 1/5] END criterion=gini, min_samples_split=9;, score=0.982 total time=   0.2s
# [CV 2/5] END criterion=gini, min_samples_split=9;, score=0.978 total time=   0.2s
# [CV 4/5] END criterion=entropy, min_samples_split=2;, score=0.980 total time=   0.2s
# [CV 5/5] END criterion=entropy, min_samples_split=2;, score=0.983 total time=   0.1s
# [CV 2/5] END criterion=entropy, min_samples_split=4;, score=0.981 total time=   0.2s
# [CV 3/5] END criterion=entropy, min_samples_split=4;, score=0.980 total time=   0.2s
# [CV 5/5] END criterion=entropy, min_samples_split=7;, score=0.982 total time=   0.1s
# [CV 1/5] END criterion=entropy, min_samples_split=8;, score=0.980 total time=   0.2s
# [CV 3/5] END criterion=entropy, min_samples_split=10;, score=0.981 total time=   0.1s
# [CV 2/5] END criterion=gini, min_samples_split=4;, score=0.977 total time=   0.2s
# [CV 4/5] END criterion=gini, min_samples_split=6;, score=0.977 total time=   0.2s
# [CV 1/5] END criterion=gini, min_samples_split=10;, score=0.981 total time=   0.2s
# [CV 1/5] END criterion=entropy, min_samples_split=4;, score=0.981 total time=   0.2s
# [CV 5/5] END criterion=entropy, min_samples_split=4;, score=0.981 total time=   0.1s
# [CV 3/5] END criterion=entropy, min_samples_split=8;, score=0.980 total time=   0.1s
# [CV 1/5] END criterion=gini, min_samples_split=2;, score=-0.618 total time=   0.2s
# [CV 5/5] END criterion=gini, min_samples_split=4;, score=-0.789 total time=   0.2s
# [CV 4/5] END criterion=gini, min_samples_split=10;, score=-0.594 total time=   0.2s
# [CV 2/5] END criterion=entropy, min_samples_split=4;, score=-0.627 total time=   0.1s
# [CV 3/5] END criterion=entropy, min_samples_split=6;, score=-0.598 total time=   0.1s
# [CV 5/5] END criterion=entropy, min_samples_split=8;, score=-0.464 total time=   0.1s
# [CV 1/5] END criterion=gini, min_samples_split=12;, score=-0.401 total time=   0.2s
# [CV 3/5] END criterion=gini, min_samples_split=14;, score=-0.341 total time=   0.2s
# [CV 1/5] END criterion=gini, min_samples_split=18;, score=-0.340 total time=   0.2s
# [CV 1/5] END criterion=entropy, min_samples_split=10;, score=-0.546 total time=   0.2s
# [CV 4/5] END criterion=entropy, min_samples_split=12;, score=-0.559 total time=   0.2s
# [CV 5/5] END criterion=entropy, min_samples_split=14;, score=-0.382 total time=   0.2s
# [CV 2/5] END criterion=entropy, min_samples_split=18;, score=-0.388 total time=   0.1s
# [CV 5/5] END criterion=entropy, min_samples_split=20;, score=-0.355 total time=   0.1s
# [CV 3/5] END criterion=gini, min_samples_split=45;, score=-0.205 total time=   0.2s
# [CV 5/5] END criterion=gini, min_samples_split=50;, score=-0.303 total time=   0.2s
# [CV 1/5] END criterion=gini, min_samples_split=65;, score=-0.182 total time=   0.2s
# [CV 3/5] END criterion=entropy, min_samples_split=45;, score=-0.229 total time=   0.1s
# [CV 2/5] END criterion=entropy, min_samples_split=55;, score=-0.244 total time=   0.2s
# [CV 4/5] END criterion=entropy, min_samples_split=60;, score=-0.249 total time=   0.1s
# [CV 3/5] END criterion=gini, min_samples_split=75;, score=-0.135 total time=   0.2s
# [CV 5/5] END criterion=gini, min_samples_split=100;, score=-0.213 total time=   0.2s
# [CV 5/5] END criterion=gini, min_samples_split=200;, score=-0.174 total time=   0.2s
# [CV 5/5] END criterion=gini, min_samples_split=250;, score=-0.164 total time=   0.2s
# [CV 1/5] END criterion=entropy, min_samples_split=150;, score=-0.115 total time=   0.1s
# [CV 4/5] END criterion=entropy, min_samples_split=200;, score=-0.141 total time=   0.2s
# [CV 5/5] END criterion=gini, min_samples_split=250;, score=-0.164 total time=   0.2s
# [CV 1/5] END criterion=gini, min_samples_split=750;, score=-0.112 total time=   0.2s
# [CV 5/5] END criterion=entropy, min_samples_split=250;, score=-0.127 total time=   0.1s
# [CV 3/5] END criterion=entropy, min_samples_split=750;, score=-0.107 total time=   0.1s
# [CV 1/5] END criterion=gini, min_samples_split=425;, score=-0.107 total time=   0.2s
# [CV 1/5] END criterion=gini, min_samples_split=450;, score=-0.111 total time=   0.2s
# [CV 1/5] END criterion=gini, min_samples_split=575;, score=-0.108 total time=   0.2s
# [CV 4/5] END criterion=entropy, min_samples_split=400;, score=-0.123 total time=   0.1s
# [CV 1/5] END criterion=entropy, min_samples_split=450;, score=-0.125 total time=   0.1s
# [CV 5/5] END criterion=entropy, min_samples_split=550;, score=-0.110 total time=   0.1s
# [CV 2/5] END criterion=gini, min_samples_split=400;, score=-0.129 total time=   0.2s
# [CV 1/5] END criterion=gini, min_samples_split=437.5;, score=nan total time=   0.0s
# [CV 4/5] END criterion=entropy, min_samples_split=400;, score=-0.123 total time=   0.1s
# [CV 5/5] END criterion=entropy, min_samples_split=400;, score=-0.108 total time=   0.1s
# [CV 4/5] END criterion=entropy, min_samples_split=450;, score=-0.122 total time=   0.1s
# [CV 3/5] END criterion=gini, min_samples_split=412;, score=-0.101 total time=   0.2s
# [CV 1/5] END criterion=gini, min_samples_split=425;, score=-0.107 total time=   0.2s
# [CV 1/5] END criterion=gini, min_samples_split=450;, score=-0.111 total time=   0.2s
# [CV 5/5] END criterion=entropy, min_samples_split=400;, score=-0.108 total time=   0.2s
# [CV 5/5] END criterion=entropy, min_samples_split=425;, score=-0.108 total time=   0.1s
# [CV 3/5] END criterion=entropy, min_samples_split=450;, score=-0.097 total time=   0.1s
# [CV 1/5] END criterion=gini, min_samples_split=412;, score=-0.105 total time=   0.2s
# [CV 4/5] END criterion=gini, min_samples_split=425;, score=-0.123 total time=   0.2s
# [CV 4/5] END criterion=gini, min_samples_split=437;, score=-0.122 total time=   0.2s
# [CV 2/5] END criterion=entropy, min_samples_split=400;, score=-0.128 total time=   0.1s
# [CV 4/5] END criterion=entropy, min_samples_split=412;, score=-0.123 total time=   0.1s
# [CV 3/5] END criterion=entropy, min_samples_split=437;, score=-0.096 total time=   0.1s
# [CV 5/5] END criterion=entropy, min_samples_split=450;, score=-0.110 total time=   0.1s
# [CV 2/5] END criterion=gini, min_samples_split=420;, score=-0.125 total time=   0.2s
# [CV 3/5] END criterion=gini, min_samples_split=430;, score=-0.101 total time=   0.2s
# [CV 2/5] END criterion=entropy, min_samples_split=425;, score=-0.128 total time=   0.1s
# [CV 1/5] END criterion=gini, min_samples_split=410;, score=-0.103 total time=   0.2s
# [CV 5/5] END criterion=gini, min_samples_split=415;, score=-0.137 total time=   0.1s
# [CV 4/5] END criterion=entropy, min_samples_split=410;, score=-0.123 total time=   0.1s
# [CV 5/5] END criterion=entropy, min_samples_split=420;, score=-0.108 total time=   0.1s
# [CV 2/5] END criterion=gini, min_samples_split=415;, score=-0.129 total time=   0.2s
# [CV 5/5] END criterion=gini, min_samples_split=417;, score=-0.137 total time=   0.1s
# [CV 3/5] END criterion=entropy, min_samples_split=412;, score=-0.096 total time=   0.1s
# [CV 3/5] END criterion=entropy, min_samples_split=417;, score=-0.096 total time=   0.1s

# %% [markdown]
# Interpret your model performance. How would it perform on different kinds of tasks? How much better is it than a "dummy" model that always chooses the majority class, or the logistic regression described at the start of the lab?

# %%
# Replace None with appropriate text
"""
None
"""

# %% [markdown]
# ## Conclusion
#
# In this lab, you practiced the end-to-end machine learning process with multiple model algorithms, including tuning the hyperparameters for those different algorithms. You saw how nonparametric models can be more flexible than linear models, potentially leading to overfitting but also potentially reducing underfitting by being able to learn non-linear relationships between variables. You also likely saw how there can be a tradeoff between speed and performance, with good metrics correlating with slow speeds.
